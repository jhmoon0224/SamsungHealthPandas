# %%
import numpy as np
import pandas as pd
import os
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
samsung_base_dir = r'D:\MyDocuments\Downloads\samsunghealth_toanyone_202101111626\samsunghealth_toanyone_202101111626'

# %%
samsung_dump_dirs = glob(os.path.join(samsung_base_dir, '*'))
samsung_dump_dir = os.path.basename(samsung_dump_dirs[0])
print(len(samsung_dump_dirs), 'dumps found, taking first:', samsung_dump_dir)

samsung_csv_paths = glob(os.path.join(samsung_base_dir, samsung_dump_dir, '*.csv'))
print(len(samsung_csv_paths), 'csvs found')
samsung_json_paths = glob(os.path.join(samsung_base_dir, samsung_dump_dir, 'jsons', '*',  '*.json'))
print(len(samsung_json_paths), 'jsons found')
# Out:
# 59 dumps found, taking first: com.samsung.health.caffeine_intake.202101111626.csv
# 0 csvs found
# 0 jsons found

# %%
food_info_df = pd.read_csv(samsung_base_dir + '\com.samsung.health.food_info.202101111626.csv', index_col=False)

# %% [markdown]
# 우선 Dataframe 구조를 한번 확인해 보자

# %%
food_info_df.head(5)
# Out:
#    potassium  vitamin_a  vitamin_c  cholesterol       description  custom  \
# 0      256.0     1.0000        0.0          0.0  353 kcal, 100 g당     NaN
# 1       83.0     1.0000        0.0          0.0   317 kcal, 90 g당     NaN
# 2       72.0    18.0000        0.0          7.0   43 kcal, 115 g당     NaN
# 3      380.0     7.0000       10.0          0.0   80 kcal, 100 g당     NaN
# 4      805.0    53.1429       22.0        260.0          841 kcal     NaN
#
#            provider_food_id  metric_serving_amount  sodium  dietary_fiber  \
# 0         samsungosp-012011                    100     4.0           3.09
# 1         samsungosp-011003                     90     5.0           0.86
# 2         samsungosp-203017                    115     5.0           0.00
# 3         samsungosp-211016                    100     2.0           1.80
# 4  HC-K00000003756-90092681                      0  1522.0           5.00
#
#    ...  info_provider    deviceuuid metric_serving_unit  saturated_fat  \
# ...

# %%
food_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3229 entries, 0 to 3228
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   potassium                       3229 non-null   float64
#  1   vitamin_a                       3229 non-null   float64
#  2   vitamin_c                       3229 non-null   float64
#  3   cholesterol                     3229 non-null   float64
#  4   description                     3229 non-null   object
#  5   custom                          0 non-null      float64
#  6   provider_food_id                3229 non-null   object
#  7   metric_serving_amount           3229 non-null   int64
#  8   sodium                          3229 non-null   float64
#  9   dietary_fiber                   3229 non-null   float64
#  10  total_fat                       3229 non-null   float64
#  11  update_time                     3229 non-null   object
# ...

# %%
food_intake_df = pd.read_csv(samsung_base_dir + '\com.samsung.health.food_intake.202101111626.csv', index_col=False)

# %%
food_intake_df.head(5)
# Out:
#                 start_time  amount  custom              update_time  \
# 0  2018-10-13 10:00:00.000     NaN     NaN  2018-10-13 10:02:50.451
# 1  2018-10-29 10:00:00.000     1.0     NaN  2018-10-29 10:00:00.298
# 2  2018-10-21 10:00:00.000     NaN     NaN  2018-10-21 10:00:46.434
# 3  2018-09-10 10:00:00.000     NaN     NaN  2018-09-10 10:00:59.401
# 4  2018-09-03 00:00:00.000     1.0     NaN  2018-09-03 00:00:01.285
#
#                create_time  meal_type name  unit  calorie time_offset  \
# 0  2018-10-13 10:02:50.451     100003  NaN   NaN    786.0    UTC+0900
# 1  2018-10-29 10:00:00.298     100003  NaN   NaN    786.0    UTC+0900
# 2  2018-10-21 10:00:46.434     100003  NaN   NaN    786.0    UTC+0900
# 3  2018-09-10 10:00:59.401     100003  NaN   NaN    801.0    UTC+0900
# 4  2018-09-03 00:00:01.285     100001  NaN   NaN    802.0    UTC+0900
#
#    deviceuuid  comment                     pkg_name  \
# 0  IOsi0gHZq8      NaN  com.sec.android.app.shealth
# ...

# %%
food_intake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4332 entries, 0 to 4331
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_time    4332 non-null   object
#  1   amount        4029 non-null   float64
#  2   custom        0 non-null      float64
#  3   update_time   4332 non-null   object
#  4   create_time   4332 non-null   object
#  5   meal_type     4332 non-null   int64
#  6   name          3185 non-null   object
#  7   unit          3443 non-null   float64
#  8   calorie       4332 non-null   float64
#  9   time_offset   4332 non-null   object
#  10  deviceuuid    4332 non-null   object
#  11  comment       0 non-null      float64
#  12  pkg_name      4332 non-null   object
#  13  datauuid      4332 non-null   object
#  14  food_info_id  4332 non-null   object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 507.8+ KB

# %%
food_intake_df['start_time'] = pd.to_datetime(food_intake_df['start_time'])
food_intake_df['update_time'] = pd.to_datetime(food_intake_df['update_time'])
food_intake_df['create_time'] = pd.to_datetime(food_intake_df['create_time'])

# %%
food_intake_df['name'].value_counts()
# Out:
# 선택형 Take Out             518
# 흑미밥                      141
# 1종과일                      63
# 음료                        62
# 단무지                       56
#                         ...
# 왕새우만두찜                     1
# 머쉬룸버거                      1
# 동치미막국수&모둠만두찜&메밀전병(김치)      1
# 사골우거지탕                     1
# 문어소바                       1
# Name: name, Length: 840, dtype: int64

# %%
food_intake_df['custom'].value_counts()
# Out:
# Series([], Name: custom, dtype: int64)

# %%
food_intake_df['unit'].value_counts()
# Out:
#  120001.0    3185
# -1.0          258
# Name: unit, dtype: int64

# %%
food_intake_df['comment'].value_counts()
# Out:
# Series([], Name: comment, dtype: int64)

# %%
food_intake_df['pkg_name'].value_counts()
# Out:
# com.welstory.healthcare        3180
# com.sec.android.app.shealth    1152
# Name: pkg_name, dtype: int64

# %%
food_intake_df.drop(['custom','unit', 'comment', 'pkg_name', 'time_offset'], axis=1, inplace=True)

# %%
food_intake_df.head(10)
# Out:
#            start_time  amount             update_time             create_time  \
# 0 2018-10-13 10:00:00     NaN 2018-10-13 10:02:50.451 2018-10-13 10:02:50.451
# 1 2018-10-29 10:00:00     1.0 2018-10-29 10:00:00.298 2018-10-29 10:00:00.298
# 2 2018-10-21 10:00:00     NaN 2018-10-21 10:00:46.434 2018-10-21 10:00:46.434
# 3 2018-09-10 10:00:00     NaN 2018-09-10 10:00:59.401 2018-09-10 10:00:59.401
# 4 2018-09-03 00:00:00     1.0 2018-09-03 00:00:01.285 2018-09-03 00:00:01.285
# 5 2018-10-15 05:00:00     1.0 2018-10-15 05:00:00.082 2018-10-15 05:00:00.082
# 6 2018-09-06 10:00:00     NaN 2018-09-06 10:01:10.353 2018-09-06 10:01:10.353
# 7 2018-10-23 10:00:00     NaN 2018-10-23 10:00:52.555 2018-10-23 10:00:52.555
# 8 2018-09-09 00:00:00     NaN 2018-09-09 00:00:55.958 2018-09-09 00:00:55.958
# 9 2018-09-10 10:00:00     1.0 2018-09-10 10:00:00.273 2018-09-10 10:00:00.273
#
#    meal_type name  calorie  deviceuuid                              datauuid  \
# ...

# %%
food_intake_df['meal_type'].value_counts()
# Out:
# 100002    2274
# 100003    1396
# 100001     662
# Name: meal_type, dtype: int64

# %%
food_info_df['name']
# Out:
# 0                잡곡밥
# 1                 쌀밥
# 2           커피,설탕,프림
# 3                바나나
# 4                가츠동
#             ...
# 3224            미니우동
# 3225           치즈돈가스
# 3226            미니우동
# 3227          양배추샐러드
# 3228    선택형 Take Out
# Name: name, Length: 3229, dtype: object
